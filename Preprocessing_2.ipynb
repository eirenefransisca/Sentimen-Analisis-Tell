# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import TweetTokenizer

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, f1_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, precision_score
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
# import pandas as pd

datar = pd.read_csv('data_anotated/indonesia_terserah.csv',encoding='latin1')
datar['Konten'] = datar['Konten'].str.lower()

print(datar['Konten'])
# Out:
# 0      source: memefess\n#indonesiaterserah #indonesi...
# 1      #indonesiaterserah \n\nfeel sorry towards thei...
# 2      #terserahindonesia \n#indonesiaterserah \n#cov...
# 3      indonesian dept. store keeps lights off to app...
# 4      semangat banget nih mokat club https://t.co/th...
# 5      me hugging myself cause no one care about my f...
# 6      barely anyone do social distancing. i swear to...
# 7      another #indonesiaterserah video, now is the o...
# 8      indonesia keren ð\n\n#indonesiaterserah htt...
# 9      here i am, making a controversial yet bold sta...
# 10     video showing indonesian shoppers racing into ...
# 11     indonesia frontliners has give up to fight the...
# 12     welcome to indonesia :)))) #indonesiaterserah ...
# 13     left: indigenous farmer cut trees in their tra...
# 14     stay strong indonesia frontliners.\nwe malaysi...
# 15     ive been seeing about indonesiaâs frontliner...
# 16     saturday quiet\ndirumah aja yokksss dan stay p...
# 17     yowwww that abs look soð¤©ð¤©ð¤©\n#bobbyind...
# 18     can't wait for all these covidiots to eventual...
# 19     despite some increases in capacity, indonesia ...
# 20     stop make stupid people famous\n\ncredit : @me...
# 21     before the government ask the people to living...
# 22     what about #indonesiaterserah #coronavirus and...
# 23     green drak\npreset lust green cov20\n#photoout...
# 24         this really hurts.... https://t.co/vftseznj3n
# 25     https://t.co/wmgedxfcdg\ndj breabeat 2020 club...
# 26     pasir ny empuk ððð\n#pantai\n#indones...
# 27     to all our indonesian doctors thank you and so...
# 28     happy #eidmubarak ðð»#indonesiaterserah h...
# 29     list-06\n@firmansentosa3\n@najatom26\n@yadie_5...
#                              ...
# 970    tagar #indonesiaterserah ramai diperbincangkan...
# 971    @tempodotco makin kesini makin ngawur statemen...
# 972            apa kabar indoneisa\n\n#indonesiaterserah
# 973    mereka juga butuh istirahat, butuh kumpul deng...
# 974    minal aidin wal faizin mohon maaf belom bisa n...
# 975    @demosocrazy maaf dalam islam kami diperintahk...
# 976    setelah #indonesiaterserah sekarang naik lagi ...
# 977                #indonesiaterserah #indonesiawhatever
# 978               dari kau ji...boss\n#indonesiaterserah
# 979    indonesia terserah\nkamu bisa apa?\n#indonesia...
# 980    #covid19 vaccine research in asean :\n\n- viet...
# 981    otw pangandaran\n. \n. \n. \ntapi boong \n\n#i...
# 982    [thread]\n\nasosiasi pengelola pusat belanja i...
# 983    #indonesiaabnormal ?\n#indonesiaterserah\ndah,...
# 984    belum ada kepastian soal vaksin, pemerintah mi...
# 985    @fvkhrie @jabirmfth kt sana front liner ramai ...
# 986    samakan corona dengan istri, solidaritas perem...
# 987    on may 16th #indonesiaterserah (âwhatever, i...
# 988    apa kabar covid? \n#indonesiaterserah \n#bangi...
# 989    harga pokok bbm yang dijual saat ini dibeli se...
# 990    @dinaerica1 sekarang mah udah ga musim corona ...
# 991    contoh pemimpin yang baik \nnyuruh stay home t...
# 992    selamat lebaran 2020.\nmohon nafkah lahir dan ...
# 993    https://t.co/nssc01js9f\n\n#indonesiaabnormal ...
# 994    in mid-april almost 88% of indonesians surveye...
# 995    @_aldiepradanaa hahah,ya, masalahe, korona iku...
# 996    @cnnindonesia bakal tambah membludak ini jmlh ...
# 997    selamat lebaran gaisss...\n\n#indahkanharimu #...
# 998    tunda juga #newnormal indonesia belum layak #i...
# 999                              https://t.co/uuttdz2tvx
# Name: Konten, Length: 1000, dtype: object

# %%
import re # impor modul regular expression
import string

emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])

emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])

#Emoji patterns
emoji_pattern = re.compile("["
         u"\U0001F600-\U0001F64F"  # emoticons
         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
         u"\U0001F680-\U0001F6FF"  # transport & map symbols
         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
         u"\U00002702-\U000027B0"
         u"\U000024C2-\U0001F251"
         "]+", flags=re.UNICODE)



import re
for i in range(len(datar)):
    txt = datar.loc[i]["Konten"]
    txt = re.sub(r'@[A-Z0-9a-z_:]+','',txt)#replace username-tags
    txt = re.sub(r'^[RT]+','',txt)#replace RT-tags
    txt = re.sub(r'[^\w\s]', '', txt)
    txt = re.sub(r'\d+','', txt)
    txt = re.sub('https?://[A-Za-z0-9./]+','',txt)#replace URLs
    txt = re.sub("[^a-zA-Z]", " ",txt)#replace hashtags
    txt = emoji_pattern.sub(r'', txt)
    datar.at[i,"Konten"]=txt


print(datar['Konten'])
# Out:
# 0      source  memefess  indonesiaterserah  indonesia...
# 1       indonesiaterserah   feel sorry towards their ...
# 2       terserahindonesia   indonesiaterserah   covid...
# 3      indonesian dept  store keeps lights off to app...
# 4                        semangat banget nih mokat club
# 5      me hugging myself cause no one care about my f...
# 6      barely anyone do social distancing  i swear to...
# 7      another  indonesiaterserah video  now is the o...
# 8              indonesia keren        indonesiaterserah
# 9      here i am  making a controversial yet bold sta...
# 10     video showing indonesian shoppers racing into ...
# 11     indonesia frontliners has give up to fight the...
# 12        welcome to indonesia        indonesiaterserah
# 13     left  indigenous farmer cut trees in their tra...
# 14     stay strong indonesia frontliners  we malaysia...
# 15     ive been seeing about indonesia   s frontliner...
# 16     saturday quiet dirumah aja yokksss dan stay pr...
# 17     yowwww that abs look so              bobbyinda...
# 18     can t wait for all these covidiots to eventual...
# 19     despite some increases in capacity  indonesia ...
# 20     stop make stupid people famous  credit     ind...
# 21     before the government ask the people to living...
# 22     what about  indonesiaterserah  coronavirus and...
# 23     green drak preset lust green cov    photooutdo...
# 24                                this really hurts
# 25      dj breabeat      clubers   youtubeoriginals  ...
# 26     pasir ny empuk               pantai  indonesia...
# 27     to all our indonesian doctors thank you and so...
# 28         happy  eidmubarak          indonesiaterserah
# 29                       list
#                              ...
# 970    tagar  indonesiaterserah ramai diperbincangkan...
# 971     makin kesini makin ngawur statement pejabat  ...
# 972              apa kabar indoneisa   indonesiaterserah
# 973    mereka juga butuh istirahat  butuh kumpul deng...
# 974    minal aidin wal faizin mohon maaf belom bisa n...
# 975     maaf dalam islam kami diperintahkan nabi kami...
# 976    setelah  indonesiaterserah sekarang naik lagi ...
# 977                 indonesiaterserah  indonesiawhatever
# 978                dari kau ji   boss  indonesiaterserah
# 979    indonesia terserah kamu bisa apa   indonesiate...
# 980     covid   vaccine research in asean      vietna...
# 981    otw pangandaran          tapi boong    indones...
# 982     thread   asosiasi pengelola pusat belanja ind...
# 983     indonesiaabnormal    indonesiaterserah dah  d...
# 984    belum ada kepastian soal vaksin  pemerintah mi...
# 985      kt sana front liner ramai guna  indonesiater...
# 986    samakan corona dengan istri  solidaritas perem...
# 987    on may   th  indonesiaterserah     whatever  i...
# 988    apa kabar covid    indonesiaterserah   bangils...
# 989    harga pokok bbm yang dijual saat ini dibeli se...
# 990     sekarang mah udah ga musim corona mba wkakaka...
# 991    contoh pemimpin yang baik  nyuruh stay home ta...
# 992    selamat lebaran       mohon nafkah lahir dan b...
# 993       indonesiaabnormal   indonesiaterserah   ind...
# 994    in mid april almost     of indonesians surveye...
# 995          hahah ya  masalahe  korona iku ing omah wae
# 996     bakal tambah membludak ini jmlh yg positif  j...
# 997    selamat lebaran gaisss      indahkanharimu  in...
# 998    tunda juga  newnormal indonesia belum layak  i...
# 999
# Name: Konten, Length: 1000, dtype: object

# %%
import nltk
from nltk.tokenize import TweetTokenizer

def identify_tokens(row):
    description = row['Konten']
    tokens = nltk.word_tokenize(str(description))
    # taken only words (not punctuation)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words

datar['Word'] = datar.apply(identify_tokens, axis=1)

print(datar['Word'])
# Out:
# 0      [source, memefess, indonesiaterserah, indonesi...
# 1      [indonesiaterserah, feel, sorry, towards, thei...
# 2      [terserahindonesia, indonesiaterserah, covid, ...
# 3      [indonesian, dept, store, keeps, lights, off, ...
# 4                   [semangat, banget, nih, mokat, club]
# 5      [me, hugging, myself, cause, no, one, care, ab...
# 6      [barely, anyone, do, social, distancing, i, sw...
# 7      [another, indonesiaterserah, video, now, is, t...
# 8                  [indonesia, keren, indonesiaterserah]
# 9      [here, i, am, making, a, controversial, yet, b...
# 10     [video, showing, indonesian, shoppers, racing,...
# 11     [indonesia, frontliners, has, give, up, to, fi...
# 12           [welcome, to, indonesia, indonesiaterserah]
# 13     [left, indigenous, farmer, cut, trees, in, the...
# 14     [stay, strong, indonesia, frontliners, we, mal...
# 15     [ive, been, seeing, about, indonesia, s, front...
# 16     [saturday, quiet, dirumah, aja, yokksss, dan, ...
# 17     [yowwww, that, abs, look, so, bobbyindaeyo, bo...
# 18     [can, t, wait, for, all, these, covidiots, to,...
# 19     [despite, some, increases, in, capacity, indon...
# 20     [stop, make, stupid, people, famous, credit, i...
# 21     [before, the, government, ask, the, people, to...
# 22     [what, about, indonesiaterserah, coronavirus, ...
# 23     [green, drak, preset, lust, green, cov, photoo...
# 24                                 [this, really, hurts]
# 25     [dj, breabeat, clubers, youtubeoriginals, yout...
# 26         [pasir, ny, empuk, pantai, indonesiaterserah]
# 27     [to, all, our, indonesian, doctors, thank, you...
# 28                [happy, eidmubarak, indonesiaterserah]
# 29                                                [list]
#                              ...
# 970    [tagar, indonesiaterserah, ramai, diperbincang...
# 971    [makin, kesini, makin, ngawur, statement, peja...
# 972           [apa, kabar, indoneisa, indonesiaterserah]
# 973    [mereka, juga, butuh, istirahat, butuh, kumpul...
# 974    [minal, aidin, wal, faizin, mohon, maaf, belom...
# 975    [maaf, dalam, islam, kami, diperintahkan, nabi...
# 976    [setelah, indonesiaterserah, sekarang, naik, l...
# 977               [indonesiaterserah, indonesiawhatever]
# 978             [dari, kau, ji, boss, indonesiaterserah]
# 979    [indonesia, terserah, kamu, bisa, apa, indones...
# 980    [covid, vaccine, research, in, asean, vietnam,...
# 981    [otw, pangandaran, tapi, boong, indonesiaterse...
# 982    [thread, asosiasi, pengelola, pusat, belanja, ...
# 983    [indonesiaabnormal, indonesiaterserah, dah, da...
# 984    [belum, ada, kepastian, soal, vaksin, pemerint...
# 985    [kt, sana, front, liner, ramai, guna, indonesi...
# 986    [samakan, corona, dengan, istri, solidaritas, ...
# 987    [on, may, th, indonesiaterserah, whatever, ind...
# 988    [apa, kabar, covid, indonesiaterserah, bangils...
# 989    [harga, pokok, bbm, yang, dijual, saat, ini, d...
# 990    [sekarang, mah, udah, ga, musim, corona, mba, ...
# 991    [contoh, pemimpin, yang, baik, nyuruh, stay, h...
# 992    [selamat, lebaran, mohon, nafkah, lahir, dan, ...
# 993    [indonesiaabnormal, indonesiaterserah, indones...
# 994    [in, mid, april, almost, of, indonesians, surv...
# 995    [hahah, ya, masalahe, korona, iku, ing, omah, ...
# 996    [bakal, tambah, membludak, ini, jmlh, yg, posi...
# 997    [selamat, lebaran, gaisss, indahkanharimu, ind...
# 998    [tunda, juga, newnormal, indonesia, belum, lay...
# 999                                                   []
# Name: Word, Length: 1000, dtype: object

# %%
# # import StemmerFactory class
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import PorterStemmer

factory = StemmerFactory()
indostemming = factory.create_stemmer()

stemming = PorterStemmer()

def stem_list(row):
    my_list = row['Word']
    stemmed_list = [indostemming.stem(word) for word in my_list]
    return (stemmed_list)

datar['Stemmed_Word'] = datar.apply(stem_list, axis=1)

print(datar['Stemmed_Word'])
# Out:
# 0      [source, memefess, indonesiaterserah, indonesi...
# 1      [indonesiaterserah, feel, sorry, towards, thei...
# 2      [terserahindonesia, indonesiaterserah, covid, ...
# 3      [indonesian, dept, store, keeps, lights, off, ...
# 4                   [semangat, banget, nih, mokat, club]
# 5      [me, hugging, myself, cause, no, one, care, ab...
# 6      [barely, anyone, do, social, distancing, i, sw...
# 7      [another, indonesiaterserah, video, now, is, t...
# 8                  [indonesia, keren, indonesiaterserah]
# 9      [here, i, am, making, a, controversial, yet, b...
# 10     [video, showing, indonesian, shoppers, racing,...
# 11     [indonesia, frontliners, has, give, up, to, fi...
# 12           [welcome, to, indonesia, indonesiaterserah]
# 13     [left, indigenous, farmer, cut, trees, in, the...
# 14     [stay, strong, indonesia, frontliners, we, mal...
# 15     [ive, been, seeing, about, indonesia, s, front...
# 16     [saturday, quiet, rumah, aja, yokksss, dan, st...
# 17     [yowwww, that, abs, look, so, bobbyindaeyo, bo...
# 18     [can, t, wait, for, all, these, covidiots, to,...
# 19     [despite, some, increases, in, capacity, indon...
# 20     [stop, make, stupid, people, famous, credit, i...
# 21     [before, the, government, ask, the, people, to...
# 22     [what, about, indonesiaterserah, coronavirus, ...
# 23     [green, drak, preset, lust, green, cov, photoo...
# 24                                 [this, really, hurts]
# 25     [dj, breabeat, clubers, youtubeoriginals, yout...
# 26         [pasir, ny, empuk, pantai, indonesiaterserah]
# 27     [to, all, our, indonesian, doctors, thank, you...
# 28                [happy, eidmubarak, indonesiaterserah]
# 29                                                [list]
#                              ...
# 970    [tagar, indonesiaterserah, ramai, bincang, di,...
# 971    [makin, kesini, makin, ngawur, statement, jaba...
# 972           [apa, kabar, indoneisa, indonesiaterserah]
# 973    [mereka, juga, butuh, istirahat, butuh, kumpul...
# 974    [mal, aidin, wal, faizin, mohon, maaf, bom, bi...
# 975    [maaf, dalam, islam, kami, perintah, nabi, kam...
# 976    [telah, indonesiaterserah, sekarang, naik, lag...
# 977               [indonesiaterserah, indonesiawhatever]
# 978             [dari, kau, ji, boss, indonesiaterserah]
# 979    [indonesia, serah, kamu, bisa, apa, indonesiat...
# 980    [covid, vaccine, research, in, asean, vietnam,...
# 981    [otw, pangandaran, tapi, boong, indonesiaterse...
# 982    [thread, asosiasi, kelola, pusat, belanja, ind...
# 983    [indonesiaabnormal, indonesiaterserah, dah, da...
# 984    [belum, ada, pasti, soal, vaksin, perintah, mi...
# 985    [kt, sana, front, liner, ramai, guna, indonesi...
# 986    [sama, corona, dengan, istri, solidaritas, per...
# 987    [on, may, th, indonesiaterserah, whatever, ind...
# 988    [apa, kabar, covid, indonesiaterserah, bangils...
# 989    [harga, pokok, bbm, yang, jual, saat, ini, bel...
# 990    [sekarang, mah, udah, ga, musim, corona, mba, ...
# 991    [contoh, pimpin, yang, baik, nyuruh, stay, hom...
# 992    [selamat, lebaran, mohon, nafkah, lahir, dan, ...
# 993    [indonesiaabnormal, indonesiaterserah, indones...
# 994    [in, mid, april, almost, of, indonesians, surv...
# 995    [hahah, ya, masalahe, korona, iku, ing, omah, ...
# 996    [bakal, tambah, membludak, ini, jmlh, yg, posi...
# 997    [selamat, lebaran, gaisss, indahkanharimu, ind...
# 998    [tunda, juga, newnormal, indonesia, belum, lay...
# 999                                                   []
# Name: Stemmed_Word, Length: 1000, dtype: object

# %%
from nltk.corpus import stopwords
stops = set(stopwords.words("indonesian"))                  

def remove_stops(row):
    my_list = row['Stemmed_Word']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

datar['Stem_Meaningful'] = datar.apply(remove_stops, axis=1)

print(datar['Stem_Meaningful'])
# Out:
# 0      [source, memefess, indonesiaterserah, indonesi...
# 1      [indonesiaterserah, feel, sorry, towards, thei...
# 2      [terserahindonesia, indonesiaterserah, covid, ...
# 3      [indonesian, dept, store, keeps, lights, off, ...
# 4                   [semangat, banget, nih, mokat, club]
# 5      [me, hugging, myself, cause, no, one, care, ab...
# 6      [barely, anyone, do, social, distancing, i, sw...
# 7      [another, indonesiaterserah, video, now, is, t...
# 8                  [indonesia, keren, indonesiaterserah]
# 9      [here, i, am, making, a, controversial, yet, b...
# 10     [video, showing, indonesian, shoppers, racing,...
# 11     [indonesia, frontliners, has, give, up, to, fi...
# 12           [welcome, to, indonesia, indonesiaterserah]
# 13     [left, indigenous, farmer, cut, trees, in, the...
# 14     [stay, strong, indonesia, frontliners, we, mal...
# 15     [ive, been, seeing, about, indonesia, s, front...
# 16     [saturday, quiet, rumah, aja, yokksss, stay, p...
# 17     [yowwww, that, abs, look, so, bobbyindaeyo, bo...
# 18     [can, t, wait, for, all, these, covidiots, to,...
# 19     [despite, some, increases, in, capacity, indon...
# 20     [stop, make, stupid, people, famous, credit, i...
# 21     [before, the, government, ask, the, people, to...
# 22     [what, about, indonesiaterserah, coronavirus, ...
# 23     [green, drak, preset, lust, green, cov, photoo...
# 24                                 [this, really, hurts]
# 25     [dj, breabeat, clubers, youtubeoriginals, yout...
# 26         [pasir, ny, empuk, pantai, indonesiaterserah]
# 27     [to, all, our, indonesian, doctors, thank, you...
# 28                [happy, eidmubarak, indonesiaterserah]
# 29                                                [list]
#                              ...
# 970    [tagar, indonesiaterserah, ramai, bincang, sos...
# 971    [kesini, ngawur, statement, jabat, indonesiate...
# 972                [kabar, indoneisa, indonesiaterserah]
# 973    [butuh, istirahat, butuh, kumpul, keluarga, bi...
# 974    [mal, aidin, wal, faizin, mohon, maaf, bom, na...
# 975    [maaf, islam, perintah, nabi, muhammad, taat, ...
# 976    [indonesiaterserah, indonesiaabnormal, ratingn...
# 977               [indonesiaterserah, indonesiawhatever]
# 978                   [kau, ji, boss, indonesiaterserah]
# 979    [indonesia, serah, indonesiaterserah, dirumahaja]
# 980    [covid, vaccine, research, in, asean, vietnam,...
# 981    [otw, pangandaran, boong, indonesiaterserah, i...
# 982    [thread, asosiasi, kelola, pusat, belanja, ind...
# 983    [indonesiaabnormal, indonesiaterserah, dah, ba...
# 984    [vaksin, perintah, masyarakat, adaptasi, hadap...
# 985         [kt, front, liner, ramai, indonesiaterserah]
# 986    [corona, istri, solidaritas, perempuan, kecam,...
# 987    [on, may, th, indonesiaterserah, whatever, ind...
# 988    [kabar, covid, indonesiaterserah, bangilsakkar...
# 989    [harga, pokok, bbm, jual, beli, harga, bbm, tu...
# 990    [mah, udah, ga, musim, corona, mba, wkakakak, ...
# 991    [contoh, pimpin, nyuruh, stay, home, ya, indon...
# 992    [selamat, lebaran, mohon, nafkah, lahir, batin...
# 993    [indonesiaabnormal, indonesiaterserah, indones...
# 994    [in, mid, april, almost, of, indonesians, surv...
# 995    [hahah, ya, masalahe, korona, iku, ing, omah, ...
# 996    [membludak, jmlh, yg, positif, jokowisilahkanm...
# 997    [selamat, lebaran, gaisss, indahkanharimu, ind...
# 998    [tunda, newnormal, indonesia, layak, indonesia...
# 999                                                   []
# Name: Stem_Meaningful, Length: 1000, dtype: object

# %%
def rejoin_words(row):
    my_list = row['Stem_Meaningful']
    joined_words = ( " ".join(my_list))
    return joined_words

datar['Processed'] = datar.apply(rejoin_words, axis=1)

print(datar['Processed'])

print(list(datar))
# Out:
# 0      source memefess indonesiaterserah indonesiater...
# 1      indonesiaterserah feel sorry towards their fro...
# 2      terserahindonesia indonesiaterserah covid coro...
# 3      indonesian dept store keeps lights off to appe...
# 4                         semangat banget nih mokat club
# 5      me hugging myself cause no one care about my f...
# 6      barely anyone do social distancing i swear to ...
# 7      another indonesiaterserah video now is the ope...
# 8                      indonesia keren indonesiaterserah
# 9      here i am making a controversial yet bold stat...
# 10     video showing indonesian shoppers racing into ...
# 11     indonesia frontliners has give up to fight the...
# 12                welcome to indonesia indonesiaterserah
# 13     left indigenous farmer cut trees in their trad...
# 14     stay strong indonesia frontliners we malaysian...
# 15     ive been seeing about indonesia s frontliner w...
# 16     saturday quiet rumah aja yokksss stay producti...
# 17     yowwww that abs look so bobbyindaeyo bobby abs...
# 18     can t wait for all these covidiots to eventual...
# 19     despite some increases in capacity indonesia i...
# 20     stop make stupid people famous credit indonesi...
# 21     before the government ask the people to living...
# 22     what about indonesiaterserah coronavirus and n...
# 23     green drak preset lust green cov photooutdoor ...
# 24                                     this really hurts
# 25     dj breabeat clubers youtubeoriginals youtubech...
# 26               pasir ny empuk pantai indonesiaterserah
# 27     to all our indonesian doctors thank you and so...
# 28                    happy eidmubarak indonesiaterserah
# 29                                                  list
#                              ...
# 970    tagar indonesiaterserah ramai bincang sosial m...
# 971      kesini ngawur statement jabat indonesiaterserah
# 972                    kabar indoneisa indonesiaterserah
# 973    butuh istirahat butuh kumpul keluarga bilang w...
# 974    mal aidin wal faizin mohon maaf bom nafkahin l...
# 975    maaf islam perintah nabi muhammad taat kpda pi...
# 976    indonesiaterserah indonesiaabnormal ratingnya ...
# 977                  indonesiaterserah indonesiawhatever
# 978                        kau ji boss indonesiaterserah
# 979         indonesia serah indonesiaterserah dirumahaja
# 980    covid vaccine research in asean vietnam begins...
# 981    otw pangandaran boong indonesiaterserah indone...
# 982    thread asosiasi kelola pusat belanja indonesia...
# 983    indonesiaabnormal indonesiaterserah dah bandun...
# 984    vaksin perintah masyarakat adaptasi hadap covi...
# 985               kt front liner ramai indonesiaterserah
# 986      corona istri solidaritas perempuan kecam mahfud
# 987    on may th indonesiaterserah whatever indonesia...
# 988      kabar covid indonesiaterserah bangilsakkarep mu
# 989            harga pokok bbm jual beli harga bbm turun
# 990    mah udah ga musim corona mba wkakakak udah gan...
# 991    contoh pimpin nyuruh stay home ya indonesiater...
# 992    selamat lebaran mohon nafkah lahir batin lebar...
# 993    indonesiaabnormal indonesiaterserah indonesiaa...
# 994    in mid april almost of indonesians surveyed in...
# 995            hahah ya masalahe korona iku ing omah wae
# 996    membludak jmlh yg positif jokowisilahkanmundur...
# 997    selamat lebaran gaisss indahkanharimu indonesi...
# 998    tunda newnormal indonesia layak indonesiaabnor...
# 999
# Name: Processed, Length: 1000, dtype: object
# ['Konten', 'Status', 'Word', 'Stemmed_Word', 'Stem_Meaningful', 'Processed']

# %%
# cols_to_drop = ['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10',
#                 'Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18',
#                 'Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26',
#                 'Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Caption','Word','Stemmed_Word','Stem_Meaningful']
cols_to_drop =['Konten','Word','Stemmed_Word','Stem_Meaningful']

datar = datar.drop(cols_to_drop,axis='columns')


datar.to_csv('data_preprocessed/indonesia_terserah_processed.csv', index=False)

# %%
import pandas as pd

datas = pd.read_csv('data_preprocessed/indonesia_terserah_processed.csv')
print(datas)
print(datas.columns)
# Out:
#       Status                                          Processed
# 0    NEGATIF  source memefess indonesiaterserah indonesiater...
# 1    NEGATIF  indonesiaterserah feel sorry towards their fro...
# 2    NEGATIF  terserahindonesia indonesiaterserah covid coro...
# 3    NEGATIF  indonesian dept store keeps lights off to appe...
# 4    POSITIF                     semangat banget nih mokat club
# 5    NEGATIF  me hugging myself cause no one care about my f...
# 6    NEGATIF  barely anyone do social distancing i swear to ...
# 7    NEGATIF  another indonesiaterserah video now is the ope...
# 8    NEGATIF                  indonesia keren indonesiaterserah
# 9    NEGATIF  here i am making a controversial yet bold stat...
# 10   NEGATIF  video showing indonesian shoppers racing into ...
# 11   NEGATIF  indonesia frontliners has give up to fight the...
# 12   NEGATIF             welcome to indonesia indonesiaterserah
# 13   NEGATIF  left indigenous farmer cut trees in their trad...
# 14   NEGATIF  stay strong indonesia frontliners we malaysian...
# 15   NEGATIF  ive been seeing about indonesia s frontliner w...
# 16   NEGATIF  saturday quiet rumah aja yokksss stay producti...
# 17   NEGATIF  yowwww that abs look so bobbyindaeyo bobby abs...
# 18   POSITIF  can t wait for all these covidiots to eventual...
# 19   NEGATIF  despite some increases in capacity indonesia i...
# 20   POSITIF  stop make stupid people famous credit indonesi...
# 21   NEGATIF  before the government ask the people to living...
# 22   NEGATIF  what about indonesiaterserah coronavirus and n...
# 23   NEGATIF  green drak preset lust green cov photooutdoor ...
# 24   NEGATIF                                  this really hurts
# 25   NEGATIF  dj breabeat clubers youtubeoriginals youtubech...
# 26   NEGATIF            pasir ny empuk pantai indonesiaterserah
# 27   NEGATIF  to all our indonesian doctors thank you and so...
# 28   NEGATIF                 happy eidmubarak indonesiaterserah
# 29   NEGATIF                                               list
# ..       ...                                                ...
# 970  NEGATIF  tagar indonesiaterserah ramai bincang sosial m...
# 971  NEGATIF    kesini ngawur statement jabat indonesiaterserah
# 972  NEGATIF                  kabar indoneisa indonesiaterserah
# 973  NEGATIF  butuh istirahat butuh kumpul keluarga bilang w...
# 974  NEGATIF  mal aidin wal faizin mohon maaf bom nafkahin l...
# 975  NEGATIF  maaf islam perintah nabi muhammad taat kpda pi...
# 976  NEGATIF  indonesiaterserah indonesiaabnormal ratingnya ...
# 977  NEGATIF                indonesiaterserah indonesiawhatever
# 978  NEGATIF                      kau ji boss indonesiaterserah
# 979  NEGATIF       indonesia serah indonesiaterserah dirumahaja
# 980  NEGATIF  covid vaccine research in asean vietnam begins...
# 981  NEGATIF  otw pangandaran boong indonesiaterserah indone...
# 982  NEGATIF  thread asosiasi kelola pusat belanja indonesia...
# 983  NEGATIF  indonesiaabnormal indonesiaterserah dah bandun...
# 984  NEGATIF  vaksin perintah masyarakat adaptasi hadap covi...
# 985  NEGATIF             kt front liner ramai indonesiaterserah
# 986  NEGATIF    corona istri solidaritas perempuan kecam mahfud
# 987  NEGATIF  on may th indonesiaterserah whatever indonesia...
# 988  NEGATIF    kabar covid indonesiaterserah bangilsakkarep mu
# 989  NEGATIF          harga pokok bbm jual beli harga bbm turun
# 990  POSITIF  mah udah ga musim corona mba wkakakak udah gan...
# 991  POSITIF  contoh pimpin nyuruh stay home ya indonesiater...
# 992  NEGATIF  selamat lebaran mohon nafkah lahir batin lebar...
# 993  NEGATIF  indonesiaabnormal indonesiaterserah indonesiaa...
# 994  NEGATIF  in mid april almost of indonesians surveyed in...
# 995  NEGATIF          hahah ya masalahe korona iku ing omah wae
# 996  NEGATIF  membludak jmlh yg positif jokowisilahkanmundur...
# 997  NEGATIF  selamat lebaran gaisss indahkanharimu indonesi...
# 998  NEGATIF  tunda newnormal indonesia layak indonesiaabnor...
# 999  NEGATIF                                                NaN
#
# [1000 rows x 2 columns]
# Index(['Status', 'Processed'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

X=datas.Processed
y=datas.Status

x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=225)

print('Banyak data x_train :',len(x_train))
print('Banyak data x_test  :',len(x_test))
print('Banyak data y_train :',len(y_train))
print('Banyak data y_test  :',len(y_test))
# Out:
# Banyak data x_train : 700
# Banyak data x_test  : 300
# Banyak data y_train : 700
# Banyak data y_test  : 300

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer, HashingVectorizer

cvec=CountVectorizer()
tvec=TfidfVectorizer()
hvec=HashingVectorizer()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn import svm
from sklearn.multiclass import OneVsRestClassifier

clf1 = RandomForestClassifier()
clf2 = LogisticRegression()
clf3 = BernoulliNB()
clf4 = SVC()
clf = OneVsRestClassifier(svm.SVC(gamma=0.01, C=100., probability=True, class_weight='balanced', kernel='linear'))

# %%
from sklearn.pipeline import Pipeline

model= Pipeline([('vectorizer',tvec)
                 ,('classifier',clf)])


model.fit(x_train.values.astype('U'),y_train.values.astype('U'))

hasil=model.predict(x_test.values.astype('U'))

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

cfm = confusion_matrix(hasil.astype(str),y_test.astype(str))

acc = accuracy_score(hasil.astype(str),y_test.astype(str))

print("Confusion Matrix :")
print(cfm)
print("Akurasi :")
print(acc)
# Out:
# Confusion Matrix :
# [[269  19   1]
#  [  7   2   0]
#  [  2   0   0]]
# Akurasi :
# 0.9033333333333333
